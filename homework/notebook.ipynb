# %%
# --- Librerías principales ---
import os
import json
import gzip
import pickle
import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    confusion_matrix, balanced_accuracy_score, f1_score, 
    precision_score, recall_score
)

# %%
def load_data(csv_file):
    df = pd.read_csv(csv_file, compression="zip")
    return df


df_train_raw = load_data("../files/input/train_data.csv.zip")
df_test_raw = load_data("../files/input/test_data.csv.zip")

print("✅ Datos cargados correctamente:")
display(df_train_raw.head())
# Out:
# ✅ Datos cargados correctamente:
#       ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  10748     310000    1          3         1   32      0      0      0
# 1  12574      10000    2          3         1   49     -1     -1     -2
# 2  29677      50000    1          2         1   28     -1     -1     -1
# 3   8857      80000    2          3         1   52      2      2      3
# 4  21099     270000    1          1         2   34      1      2      0
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      84373      57779      14163      8295      6000      4000
# 1     -1  ...       1690       1138        930         0         0      2828
# 2      0  ...      45975       1300      43987         0     46257      2200
# 3      3  ...      40748      39816      40607      3700      1600      1600
# 4      0  ...      22448      15490      17343         0      4000      2000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      3000      1000      2000                           0
# 1         0       182         0                           1
# 2      1300     43987      1386                           0
# 3         0      1600      1600                           1
# 4         0      2000      2000                           0
#
# [5 rows x 25 columns]

# %%
def data_clean(data):
    df = data.copy()
    df.rename(columns={"default payment next month": "default"}, inplace=True)
    df.drop(columns="ID", inplace=True)
    df = df[(df["EDUCATION"] != 0) & (df["MARRIAGE"] != 0)]
    df["EDUCATION"] = df["EDUCATION"].apply(lambda x: 4 if x > 4 else x)
    return df

# Aplicar limpieza y visualizar
df_train = data_clean(df_train_raw)
df_test = data_clean(df_test_raw)

print("✅ Limpieza aplicada:")
display(df_train.head())
# Out:
# ✅ Limpieza aplicada:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0     310000    1          3         1   32      0      0      0      0
# 1      10000    2          3         1   49     -1     -1     -2     -1
# 2      50000    1          2         1   28     -1     -1     -1      0
# 3      80000    2          3         1   52      2      2      3      3
# 4     270000    1          1         2   34      1      2      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      84373      57779      14163      8295      6000      4000
# 1      2  ...       1690       1138        930         0         0      2828
# 2     -1  ...      45975       1300      43987         0     46257      2200
# 3      3  ...      40748      39816      40607      3700      1600      1600
# 4      2  ...      22448      15490      17343         0      4000      2000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0      3000      1000      2000        0
# 1         0       182         0        1
# 2      1300     43987      1386        0
# 3         0      1600      1600        1
# 4         0      2000      2000        0
#
# [5 rows x 24 columns]

# %%
def split_data(data_train, data_test):
    x_train = data_train.drop(columns="default")
    y_train = data_train["default"]
    x_test = data_test.drop(columns="default")
    y_test = data_test["default"]
    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = split_data(df_train, df_test)

print("✅ División realizada correctamente:")
print(f"x_train: {x_train.shape}, y_train: {y_train.shape}")
# Out:
# ✅ División realizada correctamente:
# x_train: (20953, 23), y_train: (20953,)

# %%
def create_pipeline(estimator):
    categorical_feature = ['EDUCATION', 'SEX', 'MARRIAGE']

    preprocessor = ColumnTransformer(
        transformers=[('cat', OneHotEncoder(handle_unknown='ignore'), categorical_feature)],
        remainder='passthrough'
    )

    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('estimator', estimator)
    ])
    return pipeline

pipeline = create_pipeline(RandomForestClassifier())
print("✅ Pipeline creado correctamente:")
pipeline
# Out:
# ✅ Pipeline creado correctamente:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['EDUCATION', 'SEX',
#                                                    'MARRIAGE'])])),
#                 ('estimator', RandomForestClassifier())])

# %%
def make_grid_search(pipeline):
    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid={
            'estimator__n_estimators': [50, 100, 200],
            'estimator__max_depth': [None, 10, 20],
            'estimator__min_samples_split': [10],
            'estimator__min_samples_leaf': [1, 2, 5],
            'estimator__max_features': ['sqrt']
        },
        cv=10,
        scoring='balanced_accuracy',
        n_jobs=-1,
        verbose=2
    )
    return grid_search

grid_search = make_grid_search(pipeline)
grid_search.fit(x_train, y_train)

print("✅ GridSearch finalizado")
print("Mejores parámetros:")
grid_search.best_params_
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# ✅ GridSearch finalizado
# Mejores parámetros:
# {'estimator__max_depth': None,
#  'estimator__max_features': 'sqrt',
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 10,
#  'estimator__n_estimators': 200}

# %%
def check_estimator(estimator, x, y, dataset):
    y_pred = estimator.predict(x)
    precision = round(precision_score(y, y_pred), 4)
    balanced_accuracy = round(balanced_accuracy_score(y, y_pred), 4)
    f1 = round(f1_score(y, y_pred), 4)
    recall = round(recall_score(y, y_pred), 4)

    metrics = {
        "type": "metrics",
        "dataset": dataset,
        "precision": precision,
        "balanced_accuracy": balanced_accuracy,
        "recall": recall,
        "f1_score": f1
    }
    return metrics, y_pred

metrics_train, y_pred_train = check_estimator(grid_search, x_train, y_train, "train")
metrics_test, y_pred_test = check_estimator(grid_search, x_test, y_test, "test")

print("✅ Métricas entrenamiento:")
print(metrics_train)
print("✅ Métricas prueba:")
print(metrics_test)
# Out:
# ✅ Métricas entrenamiento:
# {'type': 'metrics', 'dataset': 'train', 'precision': 0.9718, 'balanced_accuracy': 0.8397, 'recall': 0.6853, 'f1_score': 0.8038}
# ✅ Métricas prueba:
# {'type': 'metrics', 'dataset': 'test', 'precision': 0.6693, 'balanced_accuracy': 0.6758, 'recall': 0.4056, 'f1_score': 0.5051}

# %%
#Matriz de confusión
cm = confusion_matrix(y_test, y_pred_test)  
print("✅ Matriz de confusión:")
print(cm)
# Out:
# ✅ Matriz de confusión:
# [[6691  382]
#  [1133  773]]

# %%
# %pip install optuna-integration[sklearn]
# %pip install optuna

from optuna.integration import OptunaSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

import optuna

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

pipeline = create_pipeline(RandomForestClassifier(random_state=42))

param_distributions = {
    "estimator__n_estimators": optuna.distributions.IntDistribution(100, 800),
    "estimator__max_depth": optuna.distributions.IntDistribution(3, 30),
    "estimator__min_samples_split": optuna.distributions.IntDistribution(2, 50),
    "estimator__min_samples_leaf": optuna.distributions.IntDistribution(1, 20),
    "estimator__max_features": optuna.distributions.CategoricalDistribution(["sqrt", "log2", None]),
    "estimator__class_weight": optuna.distributions.CategoricalDistribution(["balanced", "balanced_subsample", None]),
}

optuna_search = OptunaSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    cv=cv,
    scoring="balanced_accuracy",
    n_trials=60,                    # sube si tienes tiempo
    n_jobs=-1,
    random_state=42,
    refit=True
)

optuna_search.fit(x_train, y_train)
best_estimator = optuna_search.best_estimator_
optuna_search.best_params_, optuna_search.best_score_
# Out:
# Requirement already satisfied: optuna-integration[sklearn] in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (4.5.0)
# Requirement already satisfied: optuna in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna-integration[sklearn]) (4.5.0)
# Requirement already satisfied: pandas in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna-integration[sklearn]) (2.3.3)
# Requirement already satisfied: scikit-learn in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna-integration[sklearn]) (1.7.2)
# Requirement already satisfied: scipy in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna-integration[sklearn]) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (1.17.1)
# Requirement already satisfied: colorlog in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (6.10.1)
# Requirement already satisfied: numpy in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (2.0.44)
# Requirement already satisfied: tqdm in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (4.67.1)
# Requirement already satisfied: PyYAML in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna->optuna-integration[sklearn]) (6.0.3)
# Requirement already satisfied: Mako in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from alembic>=1.5.0->optuna->optuna-integration[sklearn]) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from alembic>=1.5.0->optuna->optuna-integration[sklearn]) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration[sklearn]) (3.2.4)
# Requirement already satisfied: colorama in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from colorlog->optuna->optuna-integration[sklearn]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration[sklearn]) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from pandas->optuna-integration[sklearn]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from pandas->optuna-integration[sklearn]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from pandas->optuna-integration[sklearn]) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->optuna-integration[sklearn]) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from scikit-learn->optuna-integration[sklearn]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from scikit-learn->optuna-integration[sklearn]) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\USER\AppData\Local\Temp\ipykernel_32480\353183620.py:23: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   optuna_search = OptunaSearchCV(
# [I 2025-11-09 08:43:47,366] A new study created in memory with name: no-name-a268f5ac-cfa8-4452-9d5c-7568b708a9ae
# Requirement already satisfied: optuna in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (4.5.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (1.17.1)
# Requirement already satisfied: colorlog in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: colorama in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\repos\lab-01-prediccion-del-default-usando-rf-tcarmona0108\.venv\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [I 2025-11-09 08:50:16,441] Trial 14 finished with value: 0.6561219263273734 and parameters: {'estimator__n_estimators': 174, 'estimator__max_depth': 24, 'estimator__min_samples_split': 20, 'estimator__min_samples_leaf': 6, 'estimator__max_features': 'log2', 'estimator__class_weight': None}. Best is trial 14 with value: 0.6561219263273734.
# [I 2025-11-09 08:54:47,246] Trial 15 finished with value: 0.7113426596937695 and parameters: {'estimator__n_estimators': 191, 'estimator__max_depth': 20, 'estimator__min_samples_split': 50, 'estimator__min_samples_leaf': 16, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 08:56:46,251] Trial 5 finished with value: 0.6014150582656635 and parameters: {'estimator__n_estimators': 503, 'estimator__max_depth': 3, 'estimator__min_samples_split': 23, 'estimator__min_samples_leaf': 10, 'estimator__max_features': 'sqrt', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 08:56:55,978] Trial 1 finished with value: 0.6549119769251053 and parameters: {'estimator__n_estimators': 344, 'estimator__max_depth': 27, 'estimator__min_samples_split': 33, 'estimator__min_samples_leaf': 15, 'estimator__max_features': 'log2', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:00:34,105] Trial 16 finished with value: 0.7093241048754457 and parameters: {'estimator__n_estimators': 146, 'estimator__max_depth': 13, 'estimator__min_samples_split': 5, 'estimator__min_samples_leaf': 8, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:01:12,187] Trial 0 finished with value: 0.7099983315297151 and parameters: {'estimator__n_estimators': 277, 'estimator__max_depth': 13, 'estimator__min_samples_split': 7, 'estimator__min_samples_leaf': 15, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:03:15,437] Trial 6 finished with value: 0.6581338426387878 and parameters: {'estimator__n_estimators': 393, 'estimator__max_depth': 19, 'estimator__min_samples_split': 23, 'estimator__min_samples_leaf': 4, 'estimator__max_features': 'sqrt', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:08:51,485] Trial 11 finished with value: 0.7085528938296835 and parameters: {'estimator__n_estimators': 362, 'estimator__max_depth': 14, 'estimator__min_samples_split': 27, 'estimator__min_samples_leaf': 3, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:10:19,134] Trial 3 finished with value: 0.688913287647148 and parameters: {'estimator__n_estimators': 371, 'estimator__max_depth': 26, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 1, 'estimator__max_features': 'log2', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:10:25,009] Trial 22 finished with value: 0.6550585893982517 and parameters: {'estimator__n_estimators': 136, 'estimator__max_depth': 27, 'estimator__min_samples_split': 34, 'estimator__min_samples_leaf': 12, 'estimator__max_features': 'log2', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:12:29,629] Trial 10 finished with value: 0.7099786110521398 and parameters: {'estimator__n_estimators': 519, 'estimator__max_depth': 6, 'estimator__min_samples_split': 34, 'estimator__min_samples_leaf': 3, 'estimator__max_features': 'log2', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:13:42,619] Trial 2 finished with value: 0.7108689385980955 and parameters: {'estimator__n_estimators': 790, 'estimator__max_depth': 8, 'estimator__min_samples_split': 48, 'estimator__min_samples_leaf': 8, 'estimator__max_features': 'log2', 'estimator__class_weight': 'balanced'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:15:16,978] Trial 4 finished with value: 0.7059155144351477 and parameters: {'estimator__n_estimators': 670, 'estimator__max_depth': 19, 'estimator__min_samples_split': 24, 'estimator__min_samples_leaf': 4, 'estimator__max_features': 'log2', 'estimator__class_weight': 'balanced'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:19:03,990] Trial 23 finished with value: 0.6557648501762546 and parameters: {'estimator__n_estimators': 198, 'estimator__max_depth': 27, 'estimator__min_samples_split': 38, 'estimator__min_samples_leaf': 14, 'estimator__max_features': 'sqrt', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:19:11,904] Trial 18 finished with value: 0.6342366229793208 and parameters: {'estimator__n_estimators': 554, 'estimator__max_depth': 7, 'estimator__min_samples_split': 41, 'estimator__min_samples_leaf': 19, 'estimator__max_features': 'log2', 'estimator__class_weight': None}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:26:17,720] Trial 20 finished with value: 0.7087423837617867 and parameters: {'estimator__n_estimators': 356, 'estimator__max_depth': 14, 'estimator__min_samples_split': 27, 'estimator__min_samples_leaf': 5, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:28:12,619] Trial 17 finished with value: 0.7109972796842218 and parameters: {'estimator__n_estimators': 716, 'estimator__max_depth': 13, 'estimator__min_samples_split': 40, 'estimator__min_samples_leaf': 16, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:29:33,366] Trial 19 finished with value: 0.7093917965667311 and parameters: {'estimator__n_estimators': 530, 'estimator__max_depth': 10, 'estimator__min_samples_split': 12, 'estimator__min_samples_leaf': 6, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:31:45,068] Trial 24 finished with value: 0.7087260261253945 and parameters: {'estimator__n_estimators': 395, 'estimator__max_depth': 23, 'estimator__min_samples_split': 30, 'estimator__min_samples_leaf': 13, 'estimator__max_features': 'sqrt', 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:32:14,917] Trial 9 finished with value: 0.7054612157297329 and parameters: {'estimator__n_estimators': 336, 'estimator__max_depth': 22, 'estimator__min_samples_split': 39, 'estimator__min_samples_leaf': 13, 'estimator__max_features': None, 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:40:11,446] Trial 7 finished with value: 0.7034776235082567 and parameters: {'estimator__n_estimators': 425, 'estimator__max_depth': 23, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 7, 'estimator__max_features': None, 'estimator__class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:40:19,859] Trial 8 finished with value: 0.7048539347631395 and parameters: {'estimator__n_estimators': 508, 'estimator__max_depth': 20, 'estimator__min_samples_split': 49, 'estimator__min_samples_leaf': 8, 'estimator__max_features': None, 'estimator__class_weight': 'balanced'}. Best is trial 15 with value: 0.7113426596937695.
# [I 2025-11-09 09:41:25,583] Trial 21 finished with value: 0.7054344219941757 and parameters: {'estimator__n_estimators': 629, 'estimator__max_depth': 6, 'estimator__min_samples_split': 42, 'estimator__min_samples_leaf': 1, 'estimator__max_features': None, 'estimator__class_weight': 'balanced'}. Best is trial 15 with value: 0.7113426596937695.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
